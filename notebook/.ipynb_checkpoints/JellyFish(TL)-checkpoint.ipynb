# %% [markdown]
# # 0️⃣ Set-up

# %% [markdown]
# ## Libs

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import os
import random
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='keras.src.trainers.data_adapters.py_dataset_adapter')

# %% [markdown]
# # 1️⃣ Data Loading

# %% [markdown]
# ## Load

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 12

# Training generator with augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],          # new
    channel_shift_range=20,                # new (adjust based on your images)
    fill_mode='nearest',
    validation_split=0.1
)

# Validation generator (only rescaling)
val_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_gen = train_datagen.flow_from_directory(
    '../data/Train',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=123
)

val_gen = val_datagen.flow_from_directory(
    '../data/Train',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
    shuffle=False,
    seed=123
)
# Out:
# Found 855 images belonging to 6 classes.
# Found 186 images belonging to 6 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    '../data/Test',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 34 images belonging to 6 classes.

# %% [markdown]
# ## Visualizing

# %%
def show_samples(data_dir, classes_to_show=3, images_per_class=5):
    classes = os.listdir(data_dir)
    
    plt.figure(figsize=(15, 8))
    
    for i, cls in enumerate(classes[:classes_to_show]):
        cls_path = os.path.join(data_dir, cls)
        images = os.listdir(cls_path)
        
        for j in range(images_per_class):
            img_path = os.path.join(cls_path, random.choice(images))
            img = Image.open(img_path)
            
            plt.subplot(classes_to_show, images_per_class, i * images_per_class + j + 1)
            plt.imshow(img)
            plt.title(cls)
            plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
show_samples('../data/Train')

# %%
show_samples('../data/Test')

# %% [markdown]
# # 2️⃣ Modeling

# %% [markdown]
# ## TL (VGG16)

# %%
NUM_CLASSES = 6
IMG_SIZE = (224, 224)

# Load VGG16 without top (important)
base_model = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)

# Freeze base model (important at start)
for layer in base_model.layers:
    layer.trainable = False

# Custom head
x = base_model.output
x = layers.BatchNormalization()(x)
x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)

x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x)

model = models.Model(inputs=base_model.input, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 7, 7, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 6)                   │             774 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,881,734 (56.77 MB)
#  Trainable params: 166,022 (648.52 KB)
#  Non-trainable params: 14,715,712 (56.14 MB)

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## Train

# %%
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=50
)
# Out:
# Epoch 1/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.1703 - loss: 1.8952 - val_accuracy: 0.2097 - val_loss: 1.7736
# Epoch 2/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.2719 - loss: 1.7372 - val_accuracy: 0.2957 - val_loss: 1.6856
# Epoch 3/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.3487 - loss: 1.6149 - val_accuracy: 0.5645 - val_loss: 1.5544
# Epoch 4/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.4473 - loss: 1.5074 - val_accuracy: 0.6559 - val_loss: 1.4133
# Epoch 5/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.4841 - loss: 1.4368 - val_accuracy: 0.6613 - val_loss: 1.2686
# Epoch 6/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.5494 - loss: 1.3155 - val_accuracy: 0.6774 - val_loss: 1.1412
# Epoch 7/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.5822 - loss: 1.2548 - val_accuracy: 0.6989 - val_loss: 1.0311
# Epoch 8/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.5859 - loss: 1.1738 - val_accuracy: 0.7097 - val_loss: 0.9404
# Epoch 9/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.5640 - loss: 1.1917 - val_accuracy: 0.7204 - val_loss: 0.8540
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.6501 - loss: 1.0659 - val_accuracy: 0.7473 - val_loss: 0.7843
# Epoch 11/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.6483 - loss: 1.0282 - val_accuracy: 0.7473 - val_loss: 0.7271
# Epoch 12/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.6455 - loss: 0.9911 - val_accuracy: 0.7688 - val_loss: 0.6834
# Epoch 13/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.6320 - loss: 0.9943 - val_accuracy: 0.8011 - val_loss: 0.6359
# Epoch 14/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.6821 - loss: 0.9324 - val_accuracy: 0.8118 - val_loss: 0.5910
# Epoch 15/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.6859 - loss: 0.9089 - val_accuracy: 0.8280 - val_loss: 0.5613
# Epoch 16/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.6971 - loss: 0.8376 - val_accuracy: 0.8387 - val_loss: 0.5231
# Epoch 17/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.7041 - loss: 0.8474 - val_accuracy: 0.8495 - val_loss: 0.4899
# Epoch 18/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.7088 - loss: 0.7957 - val_accuracy: 0.8710 - val_loss: 0.4564
# Epoch 19/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.7468 - loss: 0.7456 - val_accuracy: 0.8656 - val_loss: 0.4343
# Epoch 20/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.7381 - loss: 0.7637 - val_accuracy: 0.8763 - val_loss: 0.4163
# Epoch 21/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.7599 - loss: 0.7334 - val_accuracy: 0.8763 - val_loss: 0.3934
# Epoch 22/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.7371 - loss: 0.7730 - val_accuracy: 0.8710 - val_loss: 0.3684
# Epoch 23/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.7637 - loss: 0.6780 - val_accuracy: 0.8763 - val_loss: 0.3554
# Epoch 24/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.7651 - loss: 0.6712 - val_accuracy: 0.8817 - val_loss: 0.3376
# Epoch 25/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.7889 - loss: 0.6061 - val_accuracy: 0.8817 - val_loss: 0.3236
# Epoch 26/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.8126 - loss: 0.6099 - val_accuracy: 0.8817 - val_loss: 0.3144
# Epoch 27/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.7846 - loss: 0.6216 - val_accuracy: 0.9140 - val_loss: 0.2970
# Epoch 28/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.7795 - loss: 0.6366 - val_accuracy: 0.9301 - val_loss: 0.2813
# Epoch 29/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.7778 - loss: 0.6698 - val_accuracy: 0.9247 - val_loss: 0.2706
# Epoch 30/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.7669 - loss: 0.6633 - val_accuracy: 0.9140 - val_loss: 0.2624
# Epoch 31/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.7849 - loss: 0.5897 - val_accuracy: 0.9247 - val_loss: 0.2491
# Epoch 32/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.8093 - loss: 0.5758 - val_accuracy: 0.9355 - val_loss: 0.2328
# Epoch 33/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.7875 - loss: 0.6095 - val_accuracy: 0.9355 - val_loss: 0.2338
# Epoch 34/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.8099 - loss: 0.5816 - val_accuracy: 0.9462 - val_loss: 0.2175
# Epoch 35/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.8148 - loss: 0.5348 - val_accuracy: 0.9462 - val_loss: 0.2107
# Epoch 36/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.7945 - loss: 0.5461 - val_accuracy: 0.9516 - val_loss: 0.2007
# Epoch 37/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.8470 - loss: 0.4718 - val_accuracy: 0.9409 - val_loss: 0.2055
# Epoch 38/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.8293 - loss: 0.4577 - val_accuracy: 0.9462 - val_loss: 0.2052
# Epoch 39/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.8052 - loss: 0.5215 - val_accuracy: 0.9462 - val_loss: 0.1909
# Epoch 40/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.8333 - loss: 0.4958 - val_accuracy: 0.9409 - val_loss: 0.1804
# Epoch 41/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.8329 - loss: 0.4577 - val_accuracy: 0.9462 - val_loss: 0.1779
# Epoch 42/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.8444 - loss: 0.4447 - val_accuracy: 0.9516 - val_loss: 0.1678
# Epoch 43/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.8569 - loss: 0.4568 - val_accuracy: 0.9677 - val_loss: 0.1558
# Epoch 44/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.8383 - loss: 0.4468 - val_accuracy: 0.9785 - val_loss: 0.1437
# Epoch 45/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.8209 - loss: 0.4857 - val_accuracy: 0.9785 - val_loss: 0.1410
# Epoch 46/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.8698 - loss: 0.4002 - val_accuracy: 0.9785 - val_loss: 0.1391
# Epoch 47/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.8308 - loss: 0.4971 - val_accuracy: 0.9731 - val_loss: 0.1421
# Epoch 48/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.8472 - loss: 0.4507 - val_accuracy: 0.9731 - val_loss: 0.1372
# Epoch 49/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.8404 - loss: 0.4466 - val_accuracy: 0.9731 - val_loss: 0.1341
# Epoch 50/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.8655 - loss: 0.3946 - val_accuracy: 0.9785 - val_loss: 0.1239

# %% [markdown]
# ### Evaluation

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

# Accuracy
ax[0].plot(history.history['accuracy'], label='Train')
ax[0].plot(history.history['val_accuracy'], label='Validation')
ax[0].set_title('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Accuracy')
ax[0].legend()
ax[0].grid()

# Loss
ax[1].plot(history.history['loss'], label='Train')
ax[1].plot(history.history['val_loss'], label='Validation')
ax[1].set_title('Loss')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
ax[1].legend()
ax[1].grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluate On Test

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test accuracy: {test_acc:.4f}')
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 845ms/step - accuracy: 0.6403 - loss: 1.5752
# Test accuracy: 0.6765

# %% [markdown]
# ### Predict

# %%
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())   # e.g., ['class0', 'class1', ...]

# Predict probabilities
predictions = model.predict(test_generator, verbose=1)
predicted_classes = np.argmax(predictions, axis=1)
class_names = list(test_generator.class_indices.keys())
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 884ms/step

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Compute confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Display using ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)

# Plot
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax, cmap='Blues', values_format='d')
plt.title('Confusion Matrix on Test Set')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_names))
# Out:
# Classification Report:
#                          precision    recall  f1-score   support
#
#          Moon_jellyfish       0.50      0.50      0.50         6
#        barrel_jellyfish       0.67      1.00      0.80         4
#          blue_jellyfish       0.33      0.17      0.22         6
#       compass_jellyfish       1.00      0.83      0.91         6
#    lions_mane_jellyfish       0.71      0.83      0.77         6
# mauve_stinger_jellyfish       0.71      0.83      0.77         6
#
#                accuracy                           0.68        34
#               macro avg       0.65      0.69      0.66        34
#            weighted avg       0.65      0.68      0.65        34

# %% [markdown]
# ### Predict VS True

# %%
# Get total number of samples and batch size
n_samples = len(test_generator.labels)        # or len(test_generator.classes)
batch_size = test_generator.batch_size

# 3. Randomly select 10 indices
indices = np.random.choice(n_samples, 10, replace=False)

# 4. Create subplots
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
axes = axes.flatten()

# 5. For each index, fetch the corresponding image from the generator
for i, global_idx in enumerate(indices):
    ax = axes[i]
    
    # Determine which batch contains this image and its position inside the batch
    batch_idx = global_idx // batch_size
    within_idx = global_idx % batch_size
    
    # Get the batch (resets generator to avoid mixing? but we access directly)
    # Note: test_generator[batch_idx] returns (batch_images, batch_labels)
    batch_images, batch_labels = test_generator[batch_idx]
    
    # Extract the specific image and its true label
    image = batch_images[within_idx]           # shape (224,224,3), already normalized
    true_label_idx = true_classes[global_idx]  # from global true array
    pred_label_idx = predicted_classes[global_idx]
    
    true_name = class_names[true_label_idx]
    pred_name = class_names[pred_label_idx]
    
    # Display
    ax.imshow(image)
    color = 'green' if pred_label_idx == true_label_idx else 'red'
    ax.set_title(f"P: {pred_name}\nT: {true_name}", color=color)
    ax.axis('off')

# Hide any extra subplots (if fewer than 10 indices)
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()
